# %% [markdown]
# # opening and closing of file
# using open with is better bcos it close the file itself

# %%
path = "C:/Users/USER/Documents/data_analysis/datas/tmdb-movies.csv"

# %%
import json

person = '{"name": "Bob", "languages": ["English", "French"]}'
person_i= json.loads(person)

print( person_i)
print(person_i['languages'])
# Out:
# {'name': 'Bob', 'languages': ['English', 'French']}
# ['English', 'French']

# %%
import pandas as pd
df = pd.read_csv(path)

# %%
df.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline  ...  \
# 0           The park is open.  ...
# 1          What a Lovely Day.  ...
# 2  One Choice Can Destroy You  ...
#
# ...

# %%
df.isna()
# Out:
#           id  imdb_id  popularity  budget  revenue  original_title   cast  \
# 0      False    False       False   False    False           False  False
# 1      False    False       False   False    False           False  False
# 2      False    False       False   False    False           False  False
# 3      False    False       False   False    False           False  False
# 4      False    False       False   False    False           False  False
# ...      ...      ...         ...     ...      ...             ...    ...
# 10861  False    False       False   False    False           False  False
# 10862  False    False       False   False    False           False  False
# 10863  False    False       False   False    False           False  False
# 10864  False    False       False   False    False           False  False
# 10865  False    False       False   False    False           False  False
#
#        homepage  director  tagline  ...  overview  runtime  genres  \
# ...

# %%
df.isna().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
p = df
for i in p:
    df = df.fillna("missing")
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.isna().sum()
# Out:
# id                      0
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# homepage                0
# director                0
# tagline                 0
# keywords                0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %%
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
#  am goi ng to be spliting cast now

df[['cast1', 'cast2','cast3', 'cast4', 'cast5']] =df.cast.str.split(pat= '|', expand = True)
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
df.isna().sum()
# Out:
# id                        0
# imdb_id                   0
# popularity                0
# budget                    0
# revenue                   0
# original_title            0
# cast                      0
# homepage                  0
# director                  0
# tagline                   0
# keywords                  0
# overview                  0
# runtime                   0
# genres                    0
# production_companies      0
# release_date              0
# vote_count                0
# vote_average              0
# release_year              0
# budget_adj                0
# revenue_adj               0
# cast1                     0
# cast2                   220
# cast3                   310
# cast4                   419
# cast5                   732
# dtype: int64

# %%
c = df
for i in c:
    df = df.fillna("missing")
df.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline  ... vote_count vote_average  release_year  \
# 0           The park is open.  ...       5562          6.5          2015
# ...

# %%
df.isna().sum()
# Out:
# id                      0
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# homepage                0
# director                0
# tagline                 0
# keywords                0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# cast1                   0
# cast2                   0
# cast3                   0
# cast4                   0
# cast5                   0
# dtype: int64

# %%
df.shape
# Out:
# (10866, 26)

# %%
# what genure of movies generate the highest revenue with the lowest budget
gbr = df[["genres", "budget", "revenue"]]
gbr1 = gbr.sort_values(ascending = False, by = "revenue").head()
gbr1
#gbr1.to_csv("gbr1.csv", index = False)
# Out:
#                                          genres     budget     revenue
# 1386   Action|Adventure|Fantasy|Science Fiction  237000000  2781505847
# 3      Action|Adventure|Science Fiction|Fantasy  200000000  2068178225
# 5231                     Drama|Romance|Thriller  200000000  1845034188
# 4361           Science Fiction|Action|Adventure  220000000  1519557910
# 0     Action|Adventure|Science Fiction|Thriller  150000000  1513528810

# %%
gbr2 =gbr1.sort_values(ascending = False, by= "budget").head(1)
gbr2
#gbr2.to_csv("gbr2.csv", index = False)
# Out:
#                     genres  budget  revenue
# 5361  Drama|Comedy|Foreign       0        0

# %%
#Time_hour = df2[["Hour", "Quantity"]]
#timm = Time_hour.groupby(["Hour"]) ["Quantity"].sum().reset_index()
#timm.columns = ["highest_Hour", "total_Quantity"]
#timm.sort_values(ascending = False, by = "total_Quantity").head()
